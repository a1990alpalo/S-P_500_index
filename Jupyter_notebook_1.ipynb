# %%
#importing libraries to begin the project
import pandas as pd

# %%
#assigning a name to the csv file 
file_one = "Resources/sp500_companies.csv"

# %%
#Now that we have assigned a name to the csv we can load the pandas dataframe 
file_one_df = pd.read_csv(file_one)

file_one_df.head(100)
# Out:
#    Exchange Symbol                        Shortname  \
# 0       NMS   AAPL                       Apple Inc.
# 1       NMS   NVDA               NVIDIA Corporation
# 2       NMS   MSFT            Microsoft Corporation
# 3       NMS   AMZN                 Amazon.com, Inc.
# 4       NMS   GOOG                    Alphabet Inc.
# ..      ...    ...                              ...
# 95      NMS   VRTX  Vertex Pharmaceuticals Incorpor
# 96      NMS     MU          Micron Technology, Inc.
# 97      NMS   SBUX            Starbucks Corporation
# 98      NYQ    PLD                   Prologis, Inc.
# 99      NYQ    GEV                  GE Vernova Inc.
#
#                                Longname                  Sector  \
# 0                            Apple Inc.              Technology
# 1                    NVIDIA Corporation              Technology
# 2                 Microsoft Corporation              Technology
# 3                      Amazon.com, Inc.       Consumer Cyclical
# ...
